# %% [raw]
# we need to install the necessary libraries for web scraping.
#
# requests: Sends HTTP requests to fetch web content from URLs.
# BeautifulSoup: Parses and extracts data from HTML content.
# csv: Handles reading from and writing to CSV files for storing extracted data.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# %% [raw]
# Extracting Data from a Website
# We are writing a function that do Web Scraping of quote text, author names and tags from each page of the website until no further pages remain.
#
# We initialize the base URL and starting page with variables like BASE_URL and START_PAGE.
# We scrape pages by sending requests with requests.get() and parse the HTML using BeautifulSoup.
# We extract data by using find_all() for quotes, find() for author and tags and store results in a list.
# We check for the next page using find() to locate the "next" button and update the URL for the next iteration.
# Note: for this project we will be using "quotes.toscrape.com" for web scraping

# %%
BASE_URL = "http://quotes.toscrape.com/"
START_PAGE = "/page/1/"

def scrape_quotes():
    quotes_data = []
    next_page = START_PAGE
    visited_pages = set()

    while next_page:
        if next_page in visited_pages:
            print(f"Detected a loop at {next_page}, exiting...")
            break
        visited_pages.add(next_page)

        url = BASE_URL + next_page
        print(f"Scraping {url}")

        try:
            response = requests.get(url, timeout=5)
            response.raise_for_status()  # Catch 404, 500, etc.
        except requests.RequestException as e:
            print(f"Request failed: {e}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        quotes = soup.find_all("div", class_="quote")

        if not quotes:
            print(f"No quotes found on {url}, exiting...")
            break

        for quote in quotes:
            try:
                text = quote.find("span", class_="text").get_text(strip=True)
                author = quote.find("small", class_="author").get_text(strip=True)
                tags = [tag.get_text(strip=True) for tag in quote.find_all("a", class_="tag")]
                quotes_data.append({
                    "Quote": text,
                    "Author": author,
                    "Tags": ", ".join(tags)
                })
            except AttributeError as e:
                print(f"Error parsing quote block: {e}")
                continue

        next_btn = soup.find("li", class_="next")
        next_page = next_btn.find("a")["href"] if next_btn else None

    return quotes_data

# %% [raw]
# Performing Exploratory Data Analysis (EDA)
# With the data collected, we perform Exploratory Data Analysis (EDA) to understand the dataset better. We will load our CSV file and display first few rows.
#
# We import pandas to handle data manipulation with import pandas as pd.
# We load the CSV file using pd.read_csv() to read the quotes data from the file path and display the first few rows with data.head() to inspect the loaded data.

# %%
import pandas as pd

# %%
data = scrape_quotes()

df = pd.DataFrame(data)
df.to_csv(r"D:\Users\Lenovo\Downloads\quotes.csv", index=False)
# Out:
# Scraping http://quotes.toscrape.com//page/1/
# Scraping http://quotes.toscrape.com//page/2/
# Scraping http://quotes.toscrape.com//page/3/
# Scraping http://quotes.toscrape.com//page/4/
# Scraping http://quotes.toscrape.com//page/5/
# Scraping http://quotes.toscrape.com//page/6/
# Scraping http://quotes.toscrape.com//page/7/
# Scraping http://quotes.toscrape.com//page/8/
# Scraping http://quotes.toscrape.com//page/9/
# Scraping http://quotes.toscrape.com//page/10/

# %%
data = pd.read_csv(r"D:\Users\Lenovo\Downloads\quotes.csv")
data.head()
# Out:
#                                                Quote           Author  \
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# 1                            abilities, choices
# 2  inspirational, life, live, miracle, miracles
# 3              aliteracy, books, classic, humor
# 4                    be-yourself, inspirational

# %% [raw]
# Storing Data into a CSV file
# After extracting the data, we are defining a function that takes the scraped list of dictionaries and saves it as a CSV file.
#
# We check if there is data by verifying if the data is not empty.
# We save data to CSV using csv.DictWriter() to write quotes, authors and tags into a CSV file.
# We handle errors by wrapping the file saving code in a try-except block to catch any issues while saving.
# We execute the functions by calling scrape_quotes() to get the data and save_to_csv() to store it.

# %%
def save_to_csv(data, filename="quotes.csv"):
    if not data:
        print("No data to save.")
        return

    try:
        with open(filename, "w", newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=["Quote", "Author", "Tags"])
            writer.writeheader()
            writer.writerows(data)
        print(f"Saved {len(data)} quotes to {filename}")
    except Exception as e:
        print(f"Failed to save file: {e}")

if __name__ == "__main__":
    scraped_data = scrape_quotes()
    save_to_csv(scraped_data)
# Out:
# Scraping http://quotes.toscrape.com//page/1/
# Scraping http://quotes.toscrape.com//page/2/
# Scraping http://quotes.toscrape.com//page/3/
# Scraping http://quotes.toscrape.com//page/4/
# Scraping http://quotes.toscrape.com//page/5/
# Scraping http://quotes.toscrape.com//page/6/
# Scraping http://quotes.toscrape.com//page/7/
# Scraping http://quotes.toscrape.com//page/8/
# Scraping http://quotes.toscrape.com//page/9/
# Scraping http://quotes.toscrape.com//page/10/
# Saved 100 quotes to quotes.csv

# %% [raw]
# Performing Exploratory Data Analysis (EDA)
# With the data collected, we perform Exploratory Data Analysis (EDA) to understand the dataset better. We will load our CSV file and display first few rows.
#
# We import pandas to handle data manipulation with import pandas as pd.
# We load the CSV file using pd.read_csv() to read the quotes data from the file path and display the first few rows with data.head() to inspect the loaded data.

# %%
data = scrape_quotes()

import pandas as pd
df = pd.DataFrame(data)

df.to_csv(r"D:\Users\Lenovo\Downloads\quotes.csv", index=False)
print("File saved successfully
# Out:
# Scraping http://quotes.toscrape.com//page/1/
# Scraping http://quotes.toscrape.com//page/2/
# Scraping http://quotes.toscrape.com//page/3/
# Scraping http://quotes.toscrape.com//page/4/
# Scraping http://quotes.toscrape.com//page/5/
# Scraping http://quotes.toscrape.com//page/6/
# Scraping http://quotes.toscrape.com//page/7/
# Scraping http://quotes.toscrape.com//page/8/
# Scraping http://quotes.toscrape.com//page/9/
# Scraping http://quotes.toscrape.com//page/10/
# File saved successfully

# %%
data = pd.read_csv(r"D:\Users\Lenovo\Downloads\quotes.csv")
data.head()
# Out:
#                                                Quote           Author  \
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# 1                            abilities, choices
# 2  inspirational, life, live, miracle, miracles
# 3              aliteracy, books, classic, humor
# 4                    be-yourself, inspirational

# %% [raw]
#  Word Cloud Visualization
# We begin by generating a Word Cloud of the quotes to visualize the most frequently occurring words.
#
# We import libraries WordCloud from wordcloud and matplotlib.pyplot for visualization.
# We prepare the text by joining all the quotes into a single string using " ".join() and removing any missing values with dropna().
# We generate the word cloud by creating a WordCloud object with specified size and background color and using generate() to create the visualization.
# We display the word cloud using plt.imshow() for visualization.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

all_quotes = " ".join(data['Quote'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(all_quotes)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [raw]
# Top 10 Most Quoted Authors
# We are visualizing which authors have the highest number of quotes in the dataset.
#
# We split and count tags using str.split(',').explode().value_counts() to get the frequency of each tag.
# We plot the top 10 tags with plot(kind='barh') for a horizontal bar chart.
# We invert the y-axis with plt.gca().invert_yaxis() to place the most common tags at the top.

# %%
tag_counts = data['Tags'].str.split(',').explode().value_counts()

plt.figure(figsize=(10, 6))
tag_counts.head(10).plot(kind='barh', color='lightgreen')
plt.title("Top 10 Most Common Tags")
plt.xlabel("Frequency")
plt.ylabel("Tags")
plt.gca().invert_yaxis()
plt.show()

# %% [raw]
# Top 10 Most Common Tags
# We are splitting the comma separated tags and counting their frequencies to identify common themes.
#
# We calculate quote lengths using data['Quote'].apply(len) to create a new column for quote lengths.
# We plot the distribution with sns.histplot() to visualize the lengths using a histogram with a kernel density estimate (KDE).
# We display the chart using plt.show() to render the plot.

# %%
import seaborn as sns
data['Quote Length'] = data['Quote'].apply(len)

plt.figure(figsize=(10, 6))
sns.histplot(data['Quote Length'], bins=20, kde=True)
plt.title('Distribution of Quote Lengths')
plt.show()
